# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunnaOliveira/Projeto_Dados/blob/main/Projeto_im%C3%B3veis_da_uni%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel("/content/drive/MyDrive/Colab Notebooks/da-imoveisdauniao20210712.xlsx")
# Out:
#               Classe  Número do RIP  ...  Área do Terreno Total    Área da União
# 0           DOMINIAL     1010000141  ...               2.131,20         2.131,20
# 1           DOMINIAL     1010000222  ...               6.175,00         6.175,00
# 2           DOMINIAL     1010000303  ...               1.925,00         1.925,00
# 3           DOMINIAL     1010000494  ...               1.800,00         1.800,00
# 4           DOMINIAL     1010000737  ...                 660,00           660,00
# ...              ...            ...  ...                    ...              ...
# 727932  USO ESPECIAL  9997000095000  ...           1.409.098,06     1.409.098,06
# 727933  USO ESPECIAL  9997000105006  ...               8.000,00         8.000,00
# 727934  USO ESPECIAL  9997000105006  ...               8.000,00         8.000,00
# 727935  USO ESPECIAL  9997000115001  ...               4.000,00         4.000,00
# 727936  USO ESPECIAL  9997000135002  ...          17.769.594,00    17.769.594,00
#
# ...

# %%
Imóveis = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/da-imoveisdauniao20210712.xlsx")

# %%
Imóveis
# Out:
#               Classe  Número do RIP  ...  Área do Terreno Total    Área da União
# 0           DOMINIAL     1010000141  ...               2.131,20         2.131,20
# 1           DOMINIAL     1010000222  ...               6.175,00         6.175,00
# 2           DOMINIAL     1010000303  ...               1.925,00         1.925,00
# 3           DOMINIAL     1010000494  ...               1.800,00         1.800,00
# 4           DOMINIAL     1010000737  ...                 660,00           660,00
# ...              ...            ...  ...                    ...              ...
# 727932  USO ESPECIAL  9997000095000  ...           1.409.098,06     1.409.098,06
# 727933  USO ESPECIAL  9997000105006  ...               8.000,00         8.000,00
# 727934  USO ESPECIAL  9997000105006  ...               8.000,00         8.000,00
# 727935  USO ESPECIAL  9997000115001  ...               4.000,00         4.000,00
# 727936  USO ESPECIAL  9997000135002  ...          17.769.594,00    17.769.594,00
#
# ...

# %%
Imóveis.head(10)
# Out:
#      Classe  Número do RIP  ...  Área do Terreno Total    Área da União
# 0  DOMINIAL     1010000141  ...               2.131,20         2.131,20
# 1  DOMINIAL     1010000222  ...               6.175,00         6.175,00
# 2  DOMINIAL     1010000303  ...               1.925,00         1.925,00
# 3  DOMINIAL     1010000494  ...               1.800,00         1.800,00
# 4  DOMINIAL     1010000737  ...                 660,00           660,00
# 5  DOMINIAL     1010000818  ...                 700,00           700,00
# 6  DOMINIAL     1010000907  ...              10.870,00        10.870,00
# 7  DOMINIAL     1010001032  ...               8.734,28         8.734,28
# 8  DOMINIAL     1010001113  ...                 321,01           321,01
# 9  DOMINIAL     1010001202  ...               1.132,00         1.132,00
#
# [10 rows x 15 columns]
